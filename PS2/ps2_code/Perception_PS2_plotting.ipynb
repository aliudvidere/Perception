# %%
import numpy as np

# %%
Vt = np.array([[0,  1, 0],
               [10, 0, 0],
               [1,  0, 1]])

Mt = np.array([[0.0001, 0,    0],
               [0,      0.25, 0],
               [0,      0,    0.0001]])

# %%
Rt = Vt @ Mt @ Vt.T
Rt
# Out:
# array([[2.5e-01, 0.0e+00, 0.0e+00],
#        [0.0e+00, 1.0e-02, 1.0e-03],
#        [0.0e+00, 1.0e-03, 2.0e-04]])

# %%
import numpy as np
import matplotlib.pyplot as plt

def wrap_angle(angle):
    pi2 = 2 * np.pi

    while angle < -np.pi:
        angle += pi2

    while angle >= np.pi:
        angle -= pi2
        
    return angle

def plot(var, inp, outp):
    dic = {'x':1, 'y':2, 'th':3}
    v_hat = outp.f.mean_trajectory[:, dic[var] - 1]
    v = inp.f.real_robot_path[:, dic[var] - 1]
    v_std = np.sqrt(outp.f.covariance_trajectory[dic[var] - 1, dic[var] - 1, :])
    if var == 'th':
        v = np.array([wrap_angle(v_hat[i]-v[i]) for i in range(len(v))])
        v_hat = v + v
    
    t = np.linspace(0, len(v)-1, len(v))
    
    plt.subplot(3, 1, dic[var])
    plt.plot(t, v_hat - v, linewidth=3, color='blue', label='Error ' + var, alpha=0.8)
    plt.fill_between(t, 3 * v_std, -3 * v_std, color='red', alpha=0.4, label='3*sigma')
    plt.title(var + '_hat - ' + var, fontsize = 20)
    plt.legend(fontsize = 15)
    plt.grid(True)
    plt.xlabel('t', fontsize = 20)
    plt.ylabel(var + '_hat - ' + var + ', cm', fontsize = 20)

# %%
ekf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/ekf/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/ekf/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
pf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/pf/input_data.npy')
pf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/pf/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', pf_input, pf_output)
plot('y', pf_input, pf_output)
plot('th', pf_input, pf_output)

# %%
pf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/pf_output_30part/input_data.npy')
pf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/pf_output_30part/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', pf_input, pf_output)
plot('y', pf_input, pf_output)
plot('th', pf_input, pf_output)

# %%
ekf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q0/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q0/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
ekf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R0/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R0/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
ekf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R05/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R05/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
ekf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R2/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R2/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
kf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q05/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q05/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
ekf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q2/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q2/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
kf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q4/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_Q4/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)

# %%
kf_input = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R01/input_data.npy')
ekf_output = np.load('/Users/vladimirberman/Documents/Perception-in-Robotics-2023/PS2/ps2_code/results/Task_D/ekf_output_R01/output_data.npy')

# %%
plt.figure(figsize=[20,30])
plot('x', ekf_input, ekf_output)
plot('y', ekf_input, ekf_output)
plot('th', ekf_input, ekf_output)
